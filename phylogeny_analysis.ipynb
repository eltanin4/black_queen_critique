# %%
from ete3 import Tree
import numpy as np
from setup_gloome_param_files import isIndDict, genotype_dict, geneDict, good_indices
import pandas as pd
from uniqify import uniqify
from unlistify import unlistify
from copy import copy
import pickle
import re

# Getting the tree with internal nodes from gainLoss' ancestral reconstruction.
# Internal nodes are labeled with 'Nx' where x is a number, the root being
# '[N1]' and then the numbers increase.
ancTree_njs16 = Tree( 'full_proks_gainLoss_results/TheTree.INodes.ph', format=1 )

# To print the tree.
print(ancTree_njs16.get_ascii(show_internal=True))

# Getting the root of the tree.
root = ancTree_njs16&'[N1]'
nodes = list( root.traverse() )

# Getting the original traits in a trait dict.
for orgName in isIndDict:
        (ancTree_njs16&orgName).add_feature( 'isInd', isIndDict[ orgName ] )

# Writing the markNode recursive function.
def markNode( tree, node ):
    children = node.children

    # Checking if all children marked.
    for thisChild in children:
        try:
            thisChild.isInd
        except:
            markNode( tree, thisChild )

    # When you get here, all your children should be marked.
    if np.array( [ not thisChild.isInd for thisChild in children ] ).all():
        node.add_feature( 'isInd', 0 )
    else:
        node.add_feature( 'isInd', 1 )

markNode( ancTree_njs16, root )

# Getting the original genotypes in a genotype dict.
# NOTE: genotype dicts are now probability vectors.
# for orgName in isIndDict:
#         (ancTree_njs16&orgName).add_feature( 'genotype', 
#                                 np.array( list( map( int, genotype_dict[ orgName ] ) ) ) )

# Reading the gainLoss ancestral reconstructions.
anc_recon_table = pd.read_table( 
                  'full_proks_gainLoss_results/AncestralReconstructPosterior.txt' )

# Now to try the alternate 'probability' based way to infer gains and losses 
# (as in Press et. al., Gen. Res. 2016).
def reconAncestor( anc_recon_table, node ):
    if node.name == '[N1]':
        tO = anc_recon_table.loc[ anc_recon_table['Node'] == node.name[1:-1] ]
    else:
        tO = anc_recon_table.loc[ anc_recon_table['Node'] == node.name ]

    return tO['Prob'].values

# Now traversing the tree and inferring ancestral states for all unmarked nodes.
for thisNode in nodes:
    try:
        thisNode.genotype
    except:
        thisNode.add_feature( 'genotype', reconAncestor( anc_recon_table, thisNode ) )


gene_ids = sorted( uniqify( unlistify( list( geneDict.values() ) ) ) )
gene_ids = list( np.array( gene_ids )[ good_indices ] )

# Using first ancestral genotype inference method to calculate gains and losses.
def giveGainsAndLosses( parent, child ):
    gainGenes, lostGenes = set( ), set( )
    for indx, geneID in enumerate( gene_ids ):
        parentProb, childProb = parent.genotype[ indx ], child.genotype[ indx ]

        # Order is present, absent, gain and loss.
        prsnProb = parentProb * childProb
        absnProb = ( 1 - parentProb ) * ( 1 - childProb )
        gainProb = ( 1 - parentProb ) * childProb
        lossProb = parentProb * ( 1 - childProb )

        # Finding most likely event by indexing.
        probList = [ prsnProb, absnProb, gainProb, lossProb ]
        mostLikelyEvent = probList.index( max( probList ) )

        # Checking if gain or loss.
        if mostLikelyEvent == 2:
            gainGenes.add( geneID )
        elif mostLikelyEvent == 3:
            lostGenes.add( geneID )
    
    return gainGenes, lostGenes

# Using first ancestral genotype inference method to calculate gains and losses.
def isGeneRetained( parent, child, geneID ):
    indx = gene_ids.index( geneID )
    parentProb, childProb = parent.genotype[ indx ], child.genotype[ indx ]

    # Order is present, absent, gain and loss.
    prsnProb = parentProb * childProb
    absnProb = ( 1 - parentProb ) * ( 1 - childProb )
    gainProb = ( 1 - parentProb ) * childProb
    lossProb = parentProb * ( 1 - childProb )

    # Finding most likely event by indexing.
    probList = [ prsnProb, absnProb, gainProb, lossProb ]
    mostLikelyEvent = probList.index( max( probList ) )

    # Checking if gain or loss.
    if mostLikelyEvent == 0:
        return True
    return False

# Getting gain to loss ratios for each group.
def giveGLRatio( transitionSet ):
    glRatios = []
    for gainGenes, lostGenes in transitionSet:
        try:
            glRatios.append( len( gainGenes ) / len( lostGenes ) )
        except:
            pass

    return glRatios

# Now traversing the tree and inferring each branch's transitions.
ind_to_dep_GLS, ind_to_ind_GLS, dep_to_dep_GLS = [], [], []
ind_to_dep_list, ind_to_ind_list, dep_to_dep_list = [], [], []
for thisNode in nodes:
    for thisChild in thisNode.children:
        if thisNode.isInd and not thisChild.isInd:
            print( thisNode.name, thisChild.name )
            ind_to_dep_list.append( [ thisNode, thisChild ] )
            ind_to_dep_GLS.append( giveGainsAndLosses( thisNode, thisChild ) )
            
            # Test if control branch exists.
            for otherChild in thisNode.children:
                if otherChild != thisChild and otherChild.isInd:
                    ind_to_ind_list.append( [ thisNode, otherChild ] )
                    ind_to_ind_GLS.append( giveGainsAndLosses( thisNode, otherChild ) )
                    
# Saved ind_to_dep_list as a pickle object.
# Going down subsequent branches of transiting origins and measure gain/loss retention.
num_retain_trans_list, num_retain_control_list = [], []
num_gains_trans_list, num_gains_control_list = [], []
prob_retain_trans, prob_retain_control = [], []
for tI, thisTrans in enumerate( ind_to_dep_list ):
    # Getting the gained genes list for this transition.
    gainsSet = ind_to_dep_GLS[ tI ][ 0 ]
    if not gainsSet:
        continue

    for thisChild in thisTrans[1].children:
        retainedSet = set( [ gID 
                             for gID in gainsSet
                             if isGeneRetained( thisTrans[1], thisChild, gID ) ] )
        num_retain_trans = len( retainedSet )
        num_retain_trans_list.append( num_retain_trans )
        num_gains_trans_list.append( len( gainsSet ) )
        prob_retain_trans.append( num_retain_trans / len( gainsSet ) )

for tI, thisTrans in enumerate( ind_to_ind_list ):
    # Getting the gained genes list for this transition.
    gainsSet = ind_to_ind_GLS[ tI ][ 0 ]
    if not gainsSet:
        continue

    for thisChild in thisTrans[1].children:
        retainedSet = set( [ gID 
                             for gID in gainsSet
                             if isGeneRetained( thisTrans[1], thisChild, gID ) ] )
        num_retain_control = len( retainedSet )
        num_retain_control_list.append( num_retain_control )
        num_gains_control_list.append( len( gainsSet ) )
        prob_retain_control.append( num_retain_control / len( gainsSet ) )

# Getting the pathway representation for the gains.
isModuleComplete = []
for theseGains, theseLosses in ind_to_ind_GLS:
    pr_expr_dict = pickle.load( open( 'module_exprs/pr_expr_dict.dat', 'rb' ) )
    isModuleComplete.append( np.array( [] ) )
    for thisMod in pr_expr_dict:
        for x in re.findall( r'K\d{5}', pr_expr_dict[ thisMod ] ):
            pr_expr_dict[ thisMod ] = pr_expr_dict[ thisMod ].replace( 
                                      x, str( int( x[ 1: ] ) in theseGains ) )
        isModuleComplete[ -1 ] = np.append( isModuleComplete[ -1 ], 
                                            eval( pr_expr_dict[ thisMod ] ) )

control_modules_complete = unlistify( list(np.where(isModuleComplete[x])[0]) for x in range(len(isModuleComplete)) )

# Getting the pathway representation for the gains.
isModuleComplete = []
for theseGains, theseLosses in ind_to_dep_GLS:
    pr_expr_dict = pickle.load( open( 'module_exprs/pr_expr_dict.dat', 'rb' ) )
    isModuleComplete.append( np.array( [] ) )
    for thisMod in pr_expr_dict:
        for x in re.findall( r'K\d{5}', pr_expr_dict[ thisMod ] ):
            pr_expr_dict[ thisMod ] = pr_expr_dict[ thisMod ].replace( 
                                      x, str( int( x[ 1: ] ) in theseGains ) )
        isModuleComplete[ -1 ] = np.append( isModuleComplete[ -1 ], 
                                            eval( pr_expr_dict[ thisMod ] ) )

test_modules_complete = unlistify( list(np.where(isModuleComplete[x])[0]) 
                                      for x in range(len(isModuleComplete)) )

control_num_gains = np.mean( [ len( ind_to_ind_GLS[x][0] ) for x in range(len(ind_to_ind_GLS)) ] )
test_num_gains = np.mean( [ len( ind_to_dep_GLS[x][0] ) for x in range(len(ind_to_dep_GLS)) ] )
control_num_losses = np.mean( [ len( ind_to_ind_GLS[x][1] ) for x in range(len(ind_to_ind_GLS)) ] )
test_num_losses = np.mean( [ len( ind_to_dep_GLS[x][1] ) for x in range(len(ind_to_dep_GLS)) ] )
# Out:
# 100%|██████████| 247/247 [00:17<00:00, 13.62it/s]
#              /-t637000060_Carboxydothermus_hydrogenoformans
#             |
#           /N4      /-t637000316_Syntrophomonas_wolfei
#          |  |   /N6
#          |   \N5   \-t637000167_Moorella_thermoacetica
#          |     |
#          |      \-t643348537_Desulfitobacterium_hafniense
#          |
#          |      /-t641736249_Clostridium_perfringens
#          |   /N8
#          |  |  |   /-t637000080_Clostridium_tetani
#          |  |   \N9
#          |  |     |   /-t639633021_Clostridium_novyi
#          |  |      \N10
#          |  |         \-t651053017_Clostridium_acetobutylicum
#        /N3  |
#       |  |  |   /-t647000254_Fusobacterium_nucleatum
#       |  |  |  |
#       |  |  |  |               /-t639633035_Listeria_welshimeri
#       |  |  |  |            /N16
#       |  |  |  |           |  |   /-t637000152_Listeria_innocua
#       |  |  |  |           |   \N17
#       |  |  |  |           |      \-t2511231184_Listeria_monocytogenes
#       |  |  |  |           |
#       |  |  |  |           |               /-t637000140_Lactobacillus_johnsonii
#       |  |  |  |           |            /N22
#       |  |  |  |           |           |   \-t643886066_Lactobacillus_gasseri
#       |  |  |  |           |         /N21
#       |  |  |  |           |        |  |   /-t637000139_Lactobacillus_delbrueckii
#       |   \N7  |           |        |   \N23
#       |     |  |           |      /N20     \-t637000138_Lactobacillus_acidophilus
#       |     |  |           |     |  |
#       |     |  |         /N15    |  |   /-t637000142_Lactobacillus_sakei
#       |     |  |        |  |     |   \N24
#       |     |  |        |  |   /N19     \-t651053039_Lactobacillus_casei
#       |     |  |        |  |  |  |
#       |     |  |        |  |  |  |   /-t648231712_Lactobacillus_salivarius
#       |     |  |        |  |  |  |  |
#       |     |  |        |  |  |   \N25  /-t639633049_Pediococcus_pentosaceus
#       |     |  |        |  |  |     |  |
#       |     |  |        |  |  |      \N26     /-t644736381_Lactobacillus_plantarum
#       |     |  |        |  |  |        |   /N28
#       |     |  |        |  |  |        |  |   \-t639633027_Lactobacillus_brevis
#       |     |  |        |  |  |         \N27
#       |     |  |        |  |  |           |   /-t639633047_Oenococcus_oeni
#       |     |  |        |   \N18           \N29
#       |     |  |        |     |               \-t2511231143_Leuconostoc_mesenteroides
#       |     |  |        |     |
#       |     |  |        |     |      /-t651053041_Lactococcus_lactis
#       |      \N11       |     |     |
#       |        |      /N14    |     |         /-t651053075_Streptococcus_thermophilus
#       |        |     |  |     |     |      /N34
#       |        |     |  |     |   /N31    |  |   /-t640069333_Streptococcus_pyogenes
#       |        |     |  |     |  |  |   /N33  \N35
#       |        |     |  |     |  |  |  |  |      \-t638341205_Streptococcus_agalactiae
#       |        |     |  |     |  |  |  |  |
#       |        |     |  |     |  |   \N32  \-t646564575_Streptococcus_mutans
#       |        |     |  |      \N30    |
#       |        |     |  |        |     |   /-t640963052_Streptococcus_pneumoniae
#       |        |     |  |        |      \N36
#       |        |     |  |        |         \-t640069334_Streptococcus_sanguinis
#       |        |     |  |        |
#       |        |     |  |         \-t647533130_Enterococcus_faecalis
#       |        |     |  |
#     /N2        |     |  |      /-t637000201_Oceanobacillus_iheyensis
#    |  |        |     |  |   /N38
#    |  |        |     |  |  |  |   /-t637000019_Bacillus_clausii
#    |  |        |   /N13 |  |   \N39
#    |  |        |  |  |   \N37     \-t637000020_Bacillus_halodurans
#    |  |        |  |  |     |
#    |  |        |  |  |     |   /-t637000118_Geobacillus_kaustophilus
#    |  |        |  |  |     |  |
#    |  |        |  |  |      \N40     /-t650377907_Bacillus_subtilis
#    |  |        |  |  |        |   /N42
#    |  |        |  |  |        |  |   \-t639279304_Bacillus_licheniformis
#    |  |        |  |  |         \N41
#    |  |        |  |  |           |      /-t643692005_Bacillus_anthracis
#    |  |        |  |  |           |   /N44
#    |  |        |  |  |            \N43  \-t641736135_Bacillus_cereus
#    |  |        |  |  |              |
#    |  |        |  |  |               \-t637000023_Bacillus_thuringiensis
#    |  |        |  |  |
#    |  |         \N12 |   /-t637000284_Staphylococcus_saprophyticus
#    |  |           |  |  |
#    |  |           |   \N45     /-t642555160_Staphylococcus_haemolyticus
#    |  |           |     |   /N47
#    |  |           |      \N46  \-t645058812_Staphylococcus_epidermidis
#    |  |           |        |
#    |  |           |         \-t645058811_Staphylococcus_aureus
#    |  |           |
#    |  |           |      /-t637000158_Mesoplasma_florum
#    |  |           |   /N49
#    |  |           |  |  |   /-t637000181_Mycoplasma_mycoides
#    |  |           |  |   \N50
#    |  |           |  |      \-t637000174_Mycoplasma_capricolum
#    |  |           |  |
#    |  |           |  |         /-t637000175_Mycoplasma_gallisepticum
#    |  |            \N48     /N53
#    |  |              |     |  |   /-t637000183_Mycoplasma_pneumoniae
#    |  |              |     |   \N54
#    |  |              |   /N52     \-t638341133_Mycoplasma_genitalium
#    |  |              |  |  |
#    |  |              |  |  |   /-t645951878_Ureaplasma_urealyticum
#    |  |              |  |   \N55
#    |  |               \N51     \-t637000182_Mycoplasma_penetrans
#    |  |                 |
#    |  |                 |   /-t637000180_Mycoplasma_mobile
#    |  |                 |  |
#    |  |                  \N56     /-t637000184_Mycoplasma_pulmonis
#    |  |                    |   /N58
#    |  |                     \N57  \-t637000185_Mycoplasma_synoviae
#    |  |                       |
#    |  |                        \-t637000178_Mycoplasma_hyopneumoniae
#    |  |
#    |   \-t637000306_Symbiobacterium_thermophilum
#    |
#    |            /-t637000322_Thermus_thermophilus
#    |         /N62
#    |        |  |   /-t637000092_Deinococcus_radiodurans
#    |        |   \N63
#    |      /N61     \-t641228488_Deinococcus_geothermalis
#    |     |  |
#    |     |  |   /-t637000121_Gloeobacter_violaceus
# -[N1]    |  |  |
#    |     |   \N64     /-t641228501_Prochlorococcus_marinus
#    |     |     |   /N66
#    |     |     |  |   \-t637000308_Synechococcus_elongatus
#    |     |      \N65
#    |     |        |   /-t637000320_Thermosynechococcus_elongatus
#    |     |         \N67
#    |     |           |   /-t637000329_Trichodesmium_erythraeum
#    |     |            \N68
#    |     |               \-t646564504_Anabaena_variabilis
#    |     |
#    |     |      /-t637000115_Frankia_alni
#    |     |     |
#    |     |     |   /-t639633001_Acidothermus_cellulolyticus
#    |     |     |  |
#    |     |     |  |                  /-t640963015_Bifidobacterium_adolescentis
#    |     |     |  |               /N77
#    |   /N60    |  |              |   \-t649633019_Bifidobacterium_longum
#    |  |  |     |  |            /N76
#    |  |  |   /N70 |           |  |      /-t637000331_Tropheryma_whipplei
#    |  |  |  |  |  |           |  |   /N79
#    |  |  |  |  |  |         /N75  \N78  \-t637000149_Leifsonia_xyli
#    |  |  |  |  |  |        |  |     |
#    |  |  |  |  |  |        |  |      \-t639633005_Arthrobacter_aurescens
#    |  |  |  |  |  |      /N74 |
#    |  |  |  |  |  |     |  |   \-t651053059_Propionibacterium_acnes
#    |  |  |  |  |  |     |  |
#    |  |  |  |   \N71    |  |   /-t637000305_Streptomyces_coelicolor
#    |  |  |  |     |     |   \N80
#    |  |  |  |     |     |      \-t637000304_Streptomyces_avermitilis
#    |  |  |  |     |   /N73
#    |  |  |  |     |  |  |      /-t647000231_Corynebacterium_jeikeium
#    |  |  |  |     |  |  |   /N82
#    |  |  |  |     |  |  |  |  |   /-t2511231083_Corynebacterium_diphtheriae
#    |  |  |  |     |  |  |  |   \N83
#    |  |  |  |     |  |  |  |     |   /-t644736345_Corynebacterium_efficiens
#    |  |  |  |     |  |   \N81     \N84
#    |  |  |  |     |  |     |         \-t640427110_Corynebacterium_glutamicum
#    |  |   \N69    |  |     |
#    |  |     |     |  |     |   /-t637000198_Nocardia_farcinica
#    |  |     |     |  |     |  |
#    |  |     |     |  |      \N85     /-t2506783060_Mycobacterium_smegmatis
#    |  |     |      \N72       |   /N87
#    |  |     |        |        |  |   \-t639633044_Mycobacterium_vanbaalenii
#    |  |     |        |         \N86
#    |  |     |        |           |   /-t645058725_Mycobacterium_avium
#    |  |     |        |           |  |
#    |  |     |        |            \N88  /-t637000170_Mycobacterium_leprae
#    |  |     |        |              |  |
#    |  |     |        |               \N89     /-t643692028_Mycobacterium_bovis
#    |  |     |        |                 |   /N91
#    |  |     |        |                  \N90  \-t2512564073_Mycobacterium_tuberculosis
#    |  |     |        |                    |
#    |  |     |        |                     \-t642555140_Mycobacterium_ulcerans
#    |  |     |        |
#    |  |     |         \-t637000319_Thermobifida_fusca
#    |  |     |
#    |  |      \-t637000248_Rubrobacter_xylanophilus
#    |  |
#     \N59        /-t637000236_Rhodopirellula_baltica
#       |        |
#       |      /N94     /-t645951815_Chlamydia_muridarum
#       |     |  |   /N96
#       |     |  |  |   \-t637000063_Chlamydia_trachomatis
#       |     |   \N95
#       |     |     |   /-t637000065_Chlamydophila_abortus
#       |     |      \N97
#       |     |        |   /-t637000066_Chlamydophila_caviae
#       |     |         \N98
#       |     |            \-t637000067_Chlamydophila_felis
#       |     |
#       |     |                   /-t2511231194_Borrelia_garinii
#       |   /N93              /N103
#       |  |  |           /N102   \-t641736176_Borrelia_afzelii
#       |  |  |          |   |
#       |  |  |       /N101   \-t650377913_Borrelia_burgdorferi
#       |  |  |      |   |
#       |  |  |      |   |    /-t637000327_Treponema_denticola
#       |  |  |   /N100   \N104
#       |  |  |  |   |        \-t2511231215_Treponema_pallidum
#       |  |  |  |   |
#       |  |  |  |   |    /-t637000150_Leptospira_interrogans
#       |  |  |  |    \N105
#       |  |  |  |        \-t639633033_Leptospira_borgpetersenii
#       |  |   \N99
#       |  |     |        /-t637000087_Cytophaga_hutchinsonii
#       |  |     |       |
#       |  |     |    /N107       /-t650716072_Porphyromonas_gingivalis
#       |  |     |   |   |    /N109
#       |  |     |   |   |   |   |    /-t637000024_Bacteroides_fragilis
#       |  |     |   |    \N108   \N110
#       |  |      \N106      |        \-t637000026_Bacteroides_thetaiotaomicron
#       |  |         |       |
#       |  |         |        \-t639633025_Gramella_forsetii
#       |  |         |
#       |  |          \-t637000250_Salinibacter_ruber
#       |  |
#       |  |                /-t639633016_Campylobacter_fetus
#       |  |            /N114
#       |  |           |    \-t640963041_Campylobacter_jejuni
#       |  |        /N113
#        \N92      |   |    /-t637000341_Wolinella_succinogenes
#          |       |   |   |
#          |       |    \N115       /-t650377950_Helicobacter_pylori
#          |    /N112      |    /N117
#          |   |   |        \N116   \-t637000130_Helicobacter_acinonychis
#          |   |   |           |
#          |   |   |            \-t637000131_Helicobacter_hepaticus
#          |   |   |
#          |   |    \-t637000010_Aquifex_aeolicus
#          |   |
#          |   |            /-t637000204_Pelobacter_carbinolicus
#          |   |        /N120
#          |   |       |   |    /-t639633050_Pelobacter_propionicus
#          |   |       |    \N121
#          |   |       |       |    /-t648231707_Geobacter_sulfurreducens
#          |   |       |        \N122
#          |   |       |            \-t637000119_Geobacter_metallireducens
#          |   |    /N119
#          |   |   |   |            /-t637000096_Desulfovibrio_vulgaris
#          |   |   |   |        /N125
#          |   |   |   |       |   |    /-t637000145_Lawsonia_intracellularis
#          |   |   |   |    /N124   \N126
#          |   |   |   |   |   |        \-t643348538_Desulfovibrio_desulfuricans
#          |   |   |   |   |   |
#          |   |   |    \N123   \-t637000094_Desulfotalea_psychrophila
#          |   |   |       |
#          |   |   |       |    /-t639633063_Syntrophobacter_fumaroxidans
#          |   |   |        \N127
#          |   |   |            \-t637000317_Syntrophus_aciditrophicus
#          |   |   |
#           \N111  |        /-t637000030_Bdellovibrio_bacteriovorus
#              |   |    /N129
#              |   |   |   |    /-t637000186_Myxococcus_xanthus
#              |   |   |    \N130
#              |   |   |        \-t637000007_Anaeromyxobacter_dehalogenans
#              |   |   |
#              |   |   |            /-t637000325_Thiomicrospira_crunogena
#              |   |   |           |
#              |   |   |           |                        /-t639633057_Shewanella_amazonensis
#              |   |   |           |                       |
#              |   |   |           |                    /N139   /-t640069331_Shewanella_loihica
#              |   |   |           |                   |   |   |
#              |   |   |           |                   |    \N140       /-t637000257_Shewanella_frigidimarina
#              |   |   |           |                   |       |    /N142
#              |   |   |           |                   |       |   |    \-t637000256_Shewanella_denitrificans
#              |   |   |           |                   |        \N141
#              |   |   |           |                   |           |    /-t637000258_Shewanella_oneidensis
#              |   |   |           |                   |            \N143
#              |   |   |           |                   |                \-t641228507_Shewanella_baltica
#              |   |   |           |                   |
#              |   |   |           |                   |    /-t639633052_Psychromonas_ingrahamii
#              |   |   |           |                /N138  |
#              |   |   |           |               |   |   |            /-t638341150_Photobacterium_profundum
#              |   |   |           |               |   |   |           |
#              |   |   |           |               |   |   |        /N147       /-t637000335_Vibrio_parahaemolyticus
#              |   |   |           |               |   |   |       |   |    /N149
#              |   |   |           |               |   |   |       |    \N148   \-t649633107_Vibrio_vulnificus
#               \N118  |           |               |   |   |       |       |
#                  |   |           |               |   |   |       |        \-t643692054_Vibrio_cholerae
#                  |   |           |               |   |   |       |
#                  |   |           |               |   |   |       |            /-t2512564074_Pasteurella_multocida
#                  |   |           |               |   |   |    /N146       /N152
#                  |   |           |               |   |   |   |   |       |    \-t650377945_Haemophilus_influenzae
#                  |   |           |               |    \N144  |   |    /N151
#                  |   |           |               |       |   |   |   |   |    /-t637000124_Haemophilus_ducreyi
#                  |   |           |               |       |   |   |   |    \N153
#                  |   |           |               |       |   |   |   |        \-t641522604_Actinobacillus_pleuropneumoniae
#                  |   |           |               |       |   |   |   |
#                  |   |           |               |       |   |    \N150   /-t637000207_Photorhabdus_luminescens
#                  |   |           |               |       |   |       |   |
#                  |   |           |               |       |   |       |   |        /-t640069335_Yersinia_enterocolitica
#                  |   |           |               |       |   |       |   |    /N156
#                  |   |           |               |       |   |       |   |   |   |    /-t646862351_Yersinia_pestis
#                  |   |           |               |       |   |        \N154  |    \N157
#                  |   |           |            /N137      |   |           |   |        \-t637000355_Yersinia_pseudotuberculosis
#                  |   |           |           |   |       |   |           |   |
#                  |   |           |           |   |       |   |           |   |                    /-t640427143_Shigella_sonnei
#                  |   |           |           |   |        \N145          |   |                /N162
#                  |   |        /N133          |   |           |            \N155              |   |    /-t640427142_Shigella_dysenteriae
#                  |   |       |   |           |   |           |               |            /N161   \N163
#                  |   |       |   |           |   |           |               |           |   |        \-t641522650_Shigella_boydii
#                  |   |       |   |           |   |           |               |        /N160  |
#                  |   |       |   |           |   |           |               |       |   |    \-t638341089_Escherichia_coli
#                  |   |       |   |           |   |           |               |    /N159  |
#                  |   |       |   |           |   |           |               |   |   |    \-t637000265_Shigella_flexneri
#                  |   |       |   |           |   |           |               |   |   |
#                  |   |       |   |           |   |           |                \N158   \-t642555155_Salmonella_enterica
#                  |   |       |   |           |   |           |                   |
#                  |   |       |   |           |   |           |                   |        /-t650377917_Buchnera_aphidicola
#                  |   |       |   |           |   |           |                   |    /N165
#                  |   |       |   |           |   |           |                    \N164   \-t637000338_Wigglesworthia_glossinidia
#                  |   |       |   |           |   |           |                       |
#                  |   |       |   |        /N136  |           |                        \-t637000270_Sodalis_glossinidius
#                  |   |       |   |       |   |   |           |
#                  |   |       |   |       |   |   |            \-t639633004_Aeromonas_hydrophila
#                  |   |       |   |       |   |   |
#                  |   |       |   |       |   |   |    /-t637000136_Idiomarina_loihiensis
#                  |   |       |   |       |   |    \N166
#                   \N128      |   |       |   |       |    /-t637000216_Pseudoalteromonas_atlantica
#                      |       |   |       |   |        \N167
#                      |       |   |       |   |            \-t637000217_Pseudoalteromonas_haloplanktis
#                      |       |   |       |   |
#                      |       |   |       |   |            /-t650377902_Acinetobacter_baumannii
#                      |       |   |       |   |        /N170
#                      |       |   |       |   |    /N169   \-t637000227_Psychrobacter_cryohalolentis
#                      |       |   |       |   |   |   |
#                      |       |   |       |   |   |    \-t637000004_Alcanivorax_borkumensis
#                      |       |   |       |   |   |
#                      |       |   |       |   |   |        /-t637000128_Hahella_chejuensis
#                      |       |   |    /N135  |   |       |
#                      |       |   |   |   |    \N168   /N172   /-t637000075_Chromohalobacter_salexigens
#                      |       |   |   |   |       |   |   |   |
#                      |       |   |   |   |       |   |   |   |            /-t637000219_Pseudomonas_entomophila
#                      |       |   |   |   |       |   |    \N173       /N176
#                      |       |   |   |   |       |   |       |       |    \-t650716076_Pseudomonas_putida
#                      |       |   |   |   |       |   |       |    /N175
#                      |       |   |   |   |        \N171      |   |   |    /-t2505313072_Pseudomonas_syringae
#                      |       |   |   |   |           |        \N174   \N177
#                      |    /N132  |   |   |           |           |        \-t2511231156_Pseudomonas_fluorescens
#                      |   |   |   |   |   |           |           |
#                      |   |   |   |   |   |           |            \-t2511231165_Pseudomonas_aeruginosa
#                      |   |   |    \N134  |           |
#                      |   |   |       |   |            \-t637000249_Saccharophagus_degradans
#                      |   |   |       |   |
#                      |   |   |       |   |        /-t646564542_Legionella_pneumophila
#                      |   |   |       |   |    /N179
#                      |   |   |       |    \N178   \-t643348531_Coxiella_burnetii
#                      |   |   |       |       |
#                      |   |   |       |        \-t637000114_Francisella_tularensis
#                      |   |   |       |
#                      |   |   |       |        /-t647533188_Nitrosococcus_oceani
#                      |   |   |       |    /N181
#                      |   |   |       |   |    \-t639633026_Halorhodospira_halophila
#                      |   |   |       |   |
#                      |   |   |        \N180   /-t637000166_Methylococcus_capsulatus
#                      |   |   |           |   |
#                      |   |   |           |   |            /-t637000342_Xanthomonas_axonopodis
#                      |   |   |            \N182       /N185
#                      |   |   |               |    /N184   \-t637000345_Xanthomonas_campestris
#                      |   |   |               |   |   |
#                      |   |   |                \N183   \-t642555170_Xanthomonas_oryzae
#                      |   |   |                   |
#                      |   |   |                    \-t637000349_Xylella_fastidiosa
#                      |   |   |
#                      |   |   |        /-t637000074_Chromobacterium_violaceum
#                      |   |   |    /N187
#                      |   |   |   |   |    /-t642555143_Neisseria_gonorrhoeae
#                      |   |   |   |    \N188
#                      |   |   |   |        \-t637000189_Neisseria_meningitidis
#                      |   |   |   |
#                      |   |   |   |        /-t637000088_Dechloromonas_aromatica
#                      |   |   |   |       |
#                      |   |   |   |       |            /-t640069319_Methylibium_petroleiphilum
#                      |   |   |   |       |           |
#                      |   |   |   |       |        /N193       /-t637000235_Rhodoferax_ferrireducens
#                      |   |   |   |       |       |   |    /N195
#                      |   |   |   |       |       |   |   |    \-t639633051_Polaromonas_naphthalenivorans
#                      |   |   |   |       |       |    \N194
#                      |   |    \N186      |       |       |    /-t639633065_Verminephrobacter_eiseniae
#                      |   |       |    /N190   /N192       \N196
#                      |   |       |   |   |   |   |            \-t639633002_Acidovorax_avenae
#                      |   |       |   |   |   |   |
#                      |   |       |   |   |   |   |    /-t651053062_Ralstonia_solanacearum
#                      |   |       |   |   |   |   |   |
#                      |   |       |   |   |   |    \N197   /-t637000053_Burkholderia_xenovorans
#                       \N131      |   |   |   |       |   |
#                          |       |   |   |   |        \N198       /-t637000046_Burkholderia_cenocepacia
#                          |       |   |   |   |           |    /N200
#                          |       |   |    \N191          |   |    \-t637000047_Burkholderia_cepacia
#                          |       |   |       |            \N199
#                          |       |   |       |               |    /-t641736124_Burkholderia_thailandensis
#                          |       |   |       |                \N201
#                          |        \N189      |                   |    /-t638341031_Burkholderia_mallei
#                          |           |       |                    \N202
#                          |           |       |                        \-t640069306_Burkholderia_pseudomallei
#                          |           |       |
#                          |           |       |        /-t637000032_Bordetella_bronchiseptica
#                          |           |       |    /N204
#                          |           |        \N203   \-t637000033_Bordetella_parapertussis
#                          |           |           |
#                          |           |            \-t651053009_Bordetella_pertussis
#                          |           |
#                          |           |        /-t637000324_Thiobacillus_denitrificans
#                          |           |    /N206
#                          |           |   |    \-t637000165_Methylobacillus_flagellatus
#                          |            \N205
#                          |               |    /-t637000197_Nitrosospira_multiformis
#                          |                \N207
#                          |                   |    /-t637000195_Nitrosomonas_europaea
#                          |                    \N208
#                          |                        \-t637000196_Nitrosomonas_eutropha
#                          |
#                          |            /-t640753044_Rickettsia_bellii
#                          |           |
#                          |        /N211       /-t637000245_Rickettsia_prowazekii
#                          |       |   |    /N213
#                          |       |   |   |    \-t2512564075_Rickettsia_typhi
#                          |       |    \N212
#                          |       |       |    /-t637000244_Rickettsia_felis
#                          |    /N210       \N214
#                          |   |   |            \-t637000243_Rickettsia_conorii
#                          |   |   |
#                          |   |   |    /-t637000191_Neorickettsia_sennetsu
#                          |   |   |   |
#                          |   |    \N215       /-t637000009_Anaplasma_phagocytophilum
#                          |   |       |    /N217
#                          |   |       |   |    \-t645058829_Anaplasma_marginale
#                          |   |        \N216
#                          |   |           |        /-t637000097_Ehrlichia_canis
#                          |   |           |    /N219
#                          |   |            \N218   \-t638341079_Ehrlichia_chaffeensis
#                          |   |               |
#                           \N209               \-t639279308_Ehrlichia_ruminantium
#                              |
#                              |                /-t637000103_Erythrobacter_litoralis
#                              |            /N223
#                              |        /N222   \-t640427126_Novosphingobium_aromaticivorans
#                              |       |   |
#                              |    /N221   \-t637000271_Sphingopyxis_alaskensis
#                              |   |   |
#                              |   |    \-t637000356_Zymomonas_mobilis
#                              |   |
#                              |   |            /-t637000155_Magnetospirillum_magneticum
#                              |   |        /N226
#                              |   |    /N225   \-t637000241_Rhodospirillum_rubrum
#                               \N220  |   |
#                                  |   |    \-t637000122_Gluconobacter_oxydans
#                                  |   |
#                                  |   |            /-t637000135_Hyphomonas_neptunium
#                                  |   |        /N229
#                                  |   |       |    \-t637000157_Maricaulis_maris
#                                  |   |    /N228
#                                  |   |   |   |        /-t640427138_Rhodobacter_sphaeroides
#                                   \N224  |   |    /N231
#                                      |   |    \N230   \-t2511231195_Paracoccus_denitrificans
#                                      |   |       |
#                                      |   |        \-t639633056_Roseobacter_denitrificans
#                                      |   |
#                                      |   |            /-t2512875024_Mesorhizobium_loti
#                                      |   |           |
#                                      |   |           |            /-t637000027_Bartonella_henselae
#                                      |   |        /N234       /N237
#                                      |   |       |   |    /N236   \-t637000028_Bartonella_quintana
#                                       \N227      |   |   |   |
#                                          |       |   |   |    \-t639633009_Bartonella_bacilliformis
#                                          |       |    \N235
#                                          |       |       |        /-t637000040_Brucella_melitensis
#                                          |    /N233      |    /N239
#                                          |   |   |        \N238   \-t645058845_Brucella_suis
#                                          |   |   |           |
#                                          |   |   |            \-t645058842_Brucella_abortus
#                                          |   |   |
#                                          |   |   |    /-t650716086_Sinorhizobium_meliloti
#                                          |   |    \N240
#                                          |   |       |    /-t639279302_Agrobacterium_tumefaciens
#                                           \N232       \N241
#                                              |           |    /-t642979300_Rhizobium_etli
#                                              |            \N242
#                                              |                \-t644736401_Rhizobium_leguminosarum
#                                              |
#                                              |        /-t637000192_Nitrobacter_hamburgensis
#                                              |    /N244
#                                              |   |    \-t637000193_Nitrobacter_winogradskyi
#                                               \N243
#                                                  |    /-t649633091_Rhodopseudomonas_palustris
#                                                   \N245
#                                                       \-t637000038_Bradyrhizobium_japonicum
# N2 t637000306_Symbiobacterium_thermophilum
# N4 N5
# N61 N64
# N69 t637000248_Rubrobacter_xylanophilus
# N93 N94
# N111 N112
# N11 t647000254_Fusobacterium_nucleatum
# N62 N63
# N99 N100
# N118 N119
# N9 t637000080_Clostridium_tetani
# N71 t639633001_Acidothermus_cellulolyticus
# N106 t637000250_Salinibacter_ruber
# N128 N129
# N10 t639633021_Clostridium_novyi
# N72 t637000319_Thermobifida_fusca
# N107 t637000087_Cytophaga_hutchinsonii
# N49 N50
# N51 N56
# N108 N109
# N52 N55
# N133 t637000325_Thiomicrospira_crunogena
# N210 N215
# N220 N221
# N53 t637000175_Mycoplasma_gallisepticum
# N75 t651053059_Propionibacterium_acnes
# N211 t640753044_Rickettsia_bellii
# N224 N225
# N54 t638341133_Mycoplasma_genitalium
# N76 N78
# N86 N88
# N135 N178
# N180 N181
# N205 N207
# N212 N214
# N227 N228
# N182 t637000166_Methylococcus_capsulatus
# N206 t637000165_Methylobacillus_flagellatus
# N213 t637000245_Rickettsia_prowazekii
# N183 t637000349_Xylella_fastidiosa
# N166 t637000136_Idiomarina_loihiensis
# N169 t637000004_Alcanivorax_borkumensis
# N171 t637000249_Saccharophagus_degradans
# N244 t637000193_Nitrobacter_winogradskyi
# N139 t639633057_Shewanella_amazonensis
# N144 t639633052_Psychromonas_ingrahamii
# N167 t637000217_Pseudoalteromonas_haloplanktis
# N170 t637000227_Psychrobacter_cryohalolentis
# N172 t637000128_Hahella_chejuensis
# N235 N238
# N140 t640069331_Shewanella_loihica
# N146 N147
# N142 t637000257_Shewanella_frigidimarina
# N151 N153
# N152 t2512564074_Pasteurella_multocida
# N158 N164

# %%
print( sum( num_retain_control_list ) / sum( num_gains_control_list ) )
print( sum( num_retain_trans_list ) / sum( num_gains_trans_list ) )
# Out:
# 0.8672470076169749
# 0.8247863247863247
